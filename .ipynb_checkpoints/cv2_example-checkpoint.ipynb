# %%
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
img = cv2.imread("kaggle_data/train_images_512x512/0.png")
img_grey = cv2.imread("kaggle_data/train_images_512x512/0.png", 0)

plt.imshow(img)
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
# (row, column, chanel=RGB)
# (row, column) grey
print img.shape
print img_grey.shape

px = img[10, 10]
print px
# Out:
# (512, 512, 3)
# (512, 512)
# [63 45 25]
